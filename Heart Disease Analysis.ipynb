# %% [markdown]
# <a href="https://www.kaggle.com/code/aman1324/notebook5fa390a0d7?scriptVersionId=137632980" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
import seaborn as sns# data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /kaggle/input/heart-failure-prediction/heart.csv

# %%
df=pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.displot(df["Age"],kind='hist',color="red")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.distplot(df["Age"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# Out:
# /tmp/ipykernel_20/452585760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["RestingBP"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# Out:
# /tmp/ipykernel_20/2138138612.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RestingBP"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df["Cholesterol"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# Out:
# /tmp/ipykernel_20/2337020964.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df["FastingBS"],rug= True,hist=True,color='Blue',kde= True,bins=30)
## Discountinous Values
# Out:
# /tmp/ipykernel_20/2420884482.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["FastingBS"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df["MaxHR"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# Out:
# /tmp/ipykernel_20/465880847.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["MaxHR"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df["Oldpeak"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# Out:
# /tmp/ipykernel_20/480855744.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Oldpeak"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %%
sns.distplot(df["HeartDisease"],rug= True,hist=True,color='Blue',kde= True,bins=30)
## Discountinous Values
# Out:
# /tmp/ipykernel_20/1699236495.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["HeartDisease"],rug= True,hist=True,color='Blue',kde= True,bins=30)
# <Axes: xlabel='HeartDisease', ylabel='Density'>

# %%
df.groupby("Sex").size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby("ChestPainType").size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind='pie',autopct='%.1f')
# Out:
# <Axes: >

# %%
sns.violinplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(y=df['Age'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y=df['Sex'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=df['Age'],x=df['FastingBS'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='Age'>

# %%
sns.violinplot(y=df['Cholesterol'],x=df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
df.corr()
# Out:
# /tmp/ipykernel_20/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# ...

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_20/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
sns.jointplot(y=df["Age"],x=df["HeartDisease"],kind='reg')

# %%
sns.jointplot(y=df["Age"],x=df["Age"],kind='reg')

# %%
sns.jointplot(y=df["MaxHR"],x=df["Age"],kind='reg')

# %%
sns.jointplot(y=df["Age"],x=df["FastingBS"],kind='reg')

# %%
sns.jointplot(y=df["MaxHR"],x=df["Cholesterol"],kind='reg')

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
